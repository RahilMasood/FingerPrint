# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator # type: ignore

# Image dimensions
IMG_HEIGHT = 64
IMG_WIDTH = 64
BATCH_SIZE = 32

train_dir = r'C:\Users\shez8\Desktop\Technical Projects\FingerPrint\dataset_blood_group'

train_datagen = ImageDataGenerator(
    rescale=1./255,  # Normalization
    validation_split=0.2 # Splitting validation set to 20%
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (IMG_HEIGHT, IMG_WIDTH),
    batch_size = BATCH_SIZE,
    class_mode = 'categorical',
    subset = 'training'
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (IMG_HEIGHT, IMG_WIDTH),
    batch_size = BATCH_SIZE,
    class_mode = 'categorical',
    subset = 'validation'
)

# High accuracy mode using Deep CNN
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation ='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation ='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3, 3), activation ='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(256, (3, 3), activation ='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation ='relu'),
    tf.keras.layers.Dropout(0.5),  # Regularization to prevent overfitting
    tf.keras.layers.Dense(train_generator.num_classes, activation ='softmax')
])

model.compile(optimizer ='adam', loss ='categorical_crossentropy', metrics = ['accuracy'])

# Training the model
model_history = model.fit(
    train_generator,
    validation_data = validation_generator,
    epochs = 100,
    steps_per_epoch = train_generator.samples // BATCH_SIZE,
    validation_steps = validation_generator.samples // BATCH_SIZE
)

# Evaluating the model
eval = model.evaluate(validation_generator)
print(f"High Accuracy Model - Loss: {eval[0]}, Accuracy: {eval[1]}")
# Out:
# Found 4803 images belonging to 8 classes.
# Found 1197 images belonging to 8 classes.
# Epoch 1/100
# c:\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 15s 88ms/step - accuracy: 0.3216 - loss: 1.7216 - val_accuracy: 0.7576 - val_loss: 0.6296
# Epoch 2/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6562 - loss: 0.7898 - val_accuracy: 0.7956 - val_loss: 0.5617
# Epoch 3/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 14s 91ms/step - accuracy: 0.7780 - loss: 0.5918 - val_accuracy: 0.8150 - val_loss: 0.4736
# Epoch 4/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8125 - loss: 0.7133 - val_accuracy: 0.8302 - val_loss: 0.4513
# Epoch 5/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 14s 93ms/step - accuracy: 0.8324 - loss: 0.4444 - val_accuracy: 0.8260 - val_loss: 0.4611
# Epoch 6/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8125 - loss: 0.6014 - val_accuracy: 0.8294 - val_loss: 0.4408
# Epoch 7/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 14s 92ms/step - accuracy: 0.8527 - loss: 0.3960 - val_accuracy: 0.8218 - val_loss: 0.4392
# Epoch 8/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9375 - loss: 0.2300 - val_accuracy: 0.8632 - val_loss: 0.3764
# Epoch 9/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 14s 91ms/step - accuracy: 0.8730 - loss: 0.3655 - val_accuracy: 0.8514 - val_loss: 0.4120
# Epoch 10/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8750 - loss: 0.3555 - val_accuracy: 0.8412 - val_loss: 0.4477
# Epoch 11/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 14s 91ms/step - accuracy: 0.8707 - loss: 0.3308 - val_accuracy: 0.8775 - val_loss: 0.3477
# Epoch 12/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9062 - loss: 0.2412 - val_accuracy: 0.8809 - val_loss: 0.3254
# Epoch 13/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 14s 91ms/step - accuracy: 0.8891 - loss: 0.2907 - val_accuracy: 0.8556 - val_loss: 0.4009
# Epoch 14/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8750 - loss: 0.4060 - val_accuracy: 0.8640 - val_loss: 0.3725
# Epoch 15/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 14s 93ms/step - accuracy: 0.8959 - loss: 0.2696 - val_accuracy: 0.8666 - val_loss: 0.3578
# Epoch 16/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9062 - loss: 0.2428 - val_accuracy: 0.8725 - val_loss: 0.3302
# Epoch 17/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9076 - loss: 0.2391 - val_accuracy: 0.8471 - val_loss: 0.4002
# Epoch 18/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9062 - loss: 0.1987 - val_accuracy: 0.8454 - val_loss: 0.4016
# Epoch 19/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.9198 - loss: 0.2114 - val_accuracy: 0.8598 - val_loss: 0.3703
# Epoch 20/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8750 - loss: 0.2005 - val_accuracy: 0.8606 - val_loss: 0.3620
# Epoch 21/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 15s 98ms/step - accuracy: 0.9321 - loss: 0.1667 - val_accuracy: 0.8463 - val_loss: 0.5080
# Epoch 22/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9062 - loss: 0.3323 - val_accuracy: 0.8421 - val_loss: 0.4832
# Epoch 23/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 15s 98ms/step - accuracy: 0.9340 - loss: 0.1761 - val_accuracy: 0.8758 - val_loss: 0.3385
# Epoch 24/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 0.0270 - val_accuracy: 0.8750 - val_loss: 0.3675
# Epoch 25/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 14s 91ms/step - accuracy: 0.9304 - loss: 0.1817 - val_accuracy: 0.8758 - val_loss: 0.3568
# Epoch 26/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.
# Epoch 76/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9688 - loss: 0.0238 - val_accuracy: 0.8488 - val_loss: 0.8175
# Epoch 77/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.9902 - loss: 0.0323 - val_accuracy: 0.8649 - val_loss: 0.9003
# Epoch 78/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 1.0045e-04 - val_accuracy: 0.8606 - val_loss: 0.9218
# Epoch 79/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 14s 91ms/step - accuracy: 0.9904 - loss: 0.0300 - val_accuracy: 0.8438 - val_loss: 0.8907
# Epoch 80/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9688 - loss: 0.1045 - val_accuracy: 0.8480 - val_loss: 0.9053
# Epoch 81/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 14s 92ms/step - accuracy: 0.9877 - loss: 0.0435 - val_accuracy: 0.8429 - val_loss: 0.8221
# Epoch 82/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9688 - loss: 0.1128 - val_accuracy: 0.8606 - val_loss: 0.7412
# Epoch 83/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 14s 91ms/step - accuracy: 0.9921 - loss: 0.0216 - val_accuracy: 0.8590 - val_loss: 0.7555
# Epoch 84/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 2.6537e-04 - val_accuracy: 0.8573 - val_loss: 0.7561
# Epoch 85/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 14s 91ms/step - accuracy: 0.9932 - loss: 0.0238 - val_accuracy: 0.8454 - val_loss: 0.8974
# Epoch 86/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9688 - loss: 0.0443 - val_accuracy: 0.8514 - val_loss: 0.8813
# Epoch 87/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 14s 90ms/step - accuracy: 0.9852 - loss: 0.0468 - val_accuracy: 0.8438 - val_loss: 0.8009
# Epoch 88/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.8454 - val_loss: 0.7974
# Epoch 89/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 14s 92ms/step - accuracy: 0.9884 - loss: 0.0350 - val_accuracy: 0.8649 - val_loss: 0.7779
# Epoch 90/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.8682 - val_loss: 0.7718
# Epoch 91/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 14s 91ms/step - accuracy: 0.9924 - loss: 0.0266 - val_accuracy: 0.8387 - val_loss: 0.8701
# Epoch 92/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9375 - loss: 0.1206 - val_accuracy: 0.8446 - val_loss: 0.8140
# Epoch 93/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 14s 91ms/step - accuracy: 0.9913 - loss: 0.0202 - val_accuracy: 0.8649 - val_loss: 0.7458
# Epoch 94/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9688 - loss: 0.0288 - val_accuracy: 0.8632 - val_loss: 0.7614
# Epoch 95/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 14s 92ms/step - accuracy: 0.9862 - loss: 0.0401 - val_accuracy: 0.8159 - val_loss: 1.0367
# Epoch 96/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9062 - loss: 0.3607 - val_accuracy: 0.8345 - val_loss: 0.9378
# Epoch 97/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 14s 91ms/step - accuracy: 0.9847 - loss: 0.0636 - val_accuracy: 0.8666 - val_loss: 0.8167
# Epoch 98/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 5.9300e-04 - val_accuracy: 0.8649 - val_loss: 0.8190
# Epoch 99/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.9954 - loss: 0.0159 - val_accuracy: 0.8623 - val_loss: 0.8521
# Epoch 100/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 7.2244e-04 - val_accuracy: 0.8606 - val_loss: 0.8499
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8483 - loss: 0.8250
# High Accuracy Model - Loss: 0.8466482162475586, Accuracy: 0.8604845404624939

# %%
import matplotlib.pyplot as plt

def plot_accuracy(history):
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()

# Call the function to display the accuracy graph
plot_accuracy(model_history)

# %%
import numpy as np
from tensorflow.keras.preprocessing import image # type: ignore

# %%
# Load and preprocess the image
img_path = r"C:\Users\shez8\Desktop\Technical Projects\FingerPrint\testABn.jpg"
img = image.load_img(img_path, target_size=(IMG_HEIGHT, IMG_WIDTH))
img_array = image.img_to_array(img)  # Convert image to array
img_array = np.expand_dims(img_array, axis=0)  # Expand dims to match model input
img_array /= 255.0  # Normalize

prediction = model.predict(img_array)

# Decode the prediction
predicted_class = np.argmax(prediction)  # Get the class index
class_labels = list(train_generator.class_indices.keys())  # Get class labels
print(f"Predicted class: {class_labels[predicted_class]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# Predicted class: AB-

# %%
img_path = r"C:\Users\shez8\Desktop\Technical Projects\FingerPrint\testAp.jpg" 
img = image.load_img(img_path, target_size=(IMG_HEIGHT, IMG_WIDTH))
img_array = image.img_to_array(img)  # Convert image to array
img_array = np.expand_dims(img_array, axis=0)  # Expand dims to match model input
img_array /= 255.0  # Normalize

# Make a prediction
prediction = model.predict(img_array)

# Decode the prediction
predicted_class = np.argmax(prediction)  # Get the class index
class_labels = list(train_generator.class_indices.keys())  # Get class labels
print(f"Predicted class: {class_labels[predicted_class]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Predicted class: A+

# %%
img_path = r"C:\Users\shez8\Desktop\Technical Projects\FingerPrint\testOn.jpg" 
img = image.load_img(img_path, target_size=(IMG_HEIGHT, IMG_WIDTH))
img_array = image.img_to_array(img)  # Convert image to array
img_array = np.expand_dims(img_array, axis=0)  # Expand dims to match model input
img_array /= 255.0  # Normalize

# Make a prediction
prediction = model.predict(img_array)

# Decode the prediction
predicted_class = np.argmax(prediction)  # Get the class index
class_labels = list(train_generator.class_indices.keys())  # Get class labels
print(f"Predicted class: {class_labels[predicted_class]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# Predicted class: O-
